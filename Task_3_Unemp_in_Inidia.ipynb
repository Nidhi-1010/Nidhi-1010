# %% [markdown]
# Problem Statement:
# Unemployment Rate: Percentage of total labour force that is unemployed
# Labour Force: Economically Active Population(Unemployed+Unemployed)
# Labour Force Participation Rate: (Number of people Emp+ Number of People Unemployed)/Eligible Population(16 & above)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import calendar
import datetime as dt

# %%
data=pd.read_csv("/content/Unemployment.csv")
data
# Out:
#              States         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
data['Date']
# Out:
# 0       31-01-2020
# 1       29-02-2020
# 2       31-03-2020
# 3       30-04-2020
# 4       31-05-2020
#           ...
# 262     30-06-2020
# 263     31-07-2020
# 264     31-08-2020
# 265     30-09-2020
# 266     31-10-2020
# Name: Date, Length: 267, dtype: object

# %%
data.head()
# Out:
#            States         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region  \
# 0             16635535                                     41.02  South
# 1             16545652                                     40.90  South
# 2             15881197                                     39.18  South
# 3             11336911                                     33.10  South
# 4             12988845                                     36.46  South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74
# ...

# %%
data.tail()
# Out:
#           States         Date  Frequency   Estimated Unemployment Rate (%)  \
# 262  West Bengal   30-06-2020          M                              7.29
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region  \
# 262             30726310                                     40.39   East
# 263             35372506                                     46.17   East
# 264             33298644                                     47.48   East
# 265             35707239                                     47.73   East
# 266             33962549                                     45.63   East
#
#      longitude  latitude
# 262    22.9868    87.855
# ...

# %%
data.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   States                                    267 non-null    object
#  1   Date                                      267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region                                    267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
data.columns
# Out:
# Index(['States', 'Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region', 'longitude', 'latitude'],
#       dtype='object')

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 262    False
# 263    False
# 264    False
# 265    False
# 266    False
# Length: 267, dtype: bool

# %%
data.shape
# Out:
# (267, 9)

# %%
# Converting 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)



# Extracting month from 'Date' and creating a 'Month' column
data['Month'] = data['Date'].dt.month

# Converting 'Month' to integer format
data['Month_int'] = data['Month'].apply(lambda x: int(x))

# Mapping integer month values to abbreviated month names
data['Month_name'] = data['Month_int'].apply(lambda x: calendar.month_abbr[x])

# Dropping the original 'Month' column
data.drop(columns='Month', inplace=True)

data.head()
# Out:
#            States       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2020-01-31          M                              5.48
# 1  Andhra Pradesh 2020-02-29          M                              5.83
# 2  Andhra Pradesh 2020-03-31          M                              5.79
# 3  Andhra Pradesh 2020-04-30          M                             20.51
# 4  Andhra Pradesh 2020-05-31          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region  \
# 0             16635535                                     41.02  South
# 1             16545652                                     40.90  South
# 2             15881197                                     39.18  South
# 3             11336911                                     33.10  South
# 4             12988845                                     36.46  South
#
#    longitude  latitude  Month_int Month_name
# ...

# %%
#Renaming all columns
data.columns = ["States", "Date", "Frequency", "Estimated Unemployment Rate", "Estimated Employed", "Estimated Labor Participation Rate", "Region", "Longitude", "Latitude", "Month_Number", "Month_Name"]
data
# Out:
#              States       Date Frequency  Estimated Unemployment Rate  \
# 0    Andhra Pradesh 2020-01-31         M                         5.48
# 1    Andhra Pradesh 2020-02-29         M                         5.83
# 2    Andhra Pradesh 2020-03-31         M                         5.79
# 3    Andhra Pradesh 2020-04-30         M                        20.51
# 4    Andhra Pradesh 2020-05-31         M                        17.43
# ..              ...        ...       ...                          ...
# 262     West Bengal 2020-06-30         M                         7.29
# 263     West Bengal 2020-07-31         M                         6.83
# 264     West Bengal 2020-08-31         M                        14.87
# 265     West Bengal 2020-09-30         M                         9.35
# 266     West Bengal 2020-10-31         M                         9.98
#
#      Estimated Employed  Estimated Labor Participation Rate Region  Longitude  \
# ...

# %%
#Looking at the correlation of the dataset
correlation_matrix=data.corr
correlation_matrix
# Out:
# <bound method DataFrame.corr of              States       Date Frequency  Estimated Unemployment Rate  \
# 0    Andhra Pradesh 2020-01-31         M                         5.48
# 1    Andhra Pradesh 2020-02-29         M                         5.83
# 2    Andhra Pradesh 2020-03-31         M                         5.79
# 3    Andhra Pradesh 2020-04-30         M                        20.51
# 4    Andhra Pradesh 2020-05-31         M                        17.43
# ..              ...        ...       ...                          ...
# 262     West Bengal 2020-06-30         M                         7.29
# 263     West Bengal 2020-07-31         M                         6.83
# 264     West Bengal 2020-08-31         M                        14.87
# 265     West Bengal 2020-09-30         M                         9.35
# 266     West Bengal 2020-10-31         M                         9.98
#
#      Estimated Employed  Estimated Labor Participation Rate Region  Longitude  \
# ...

# %%
#Plotting the heat map for visulaisation
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(), cmap="coolwarm" )
plt.show()
# Out:
# <ipython-input-14-a24af6f8a2a8>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), cmap="coolwarm" )

# %%
# Group by Region and sum the Employees column
grouped_data = data.groupby('Region')['Estimated Employed'].sum().reset_index()

# Print the grouped data
print(grouped_data)


plt.show
# Out:
#       Region  Estimated Employed
# 0       East           784094676
# 1      North          1032726546
# 2  Northeast           137450010
# 3      South           842435360
# 4       West           931175636
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(data['Estimated Employed'].dtype)
# Out:
# int64

# %%
#See the unemployment rate according to different regions of India
data.columns = ["States", "Date", "Frequency", "Estimated Unemployment Rate", "Estimated Employed", "Estimated Labor Participation Rate", "Region", "Longitude", "Latitude", "Month_Number", "Month_Name"]
data
plt.figure(figsize=(10,6))
sns.histplot(x='Estimated Unemployment Rate',hue='Region',data=data)
plt.title('Indian Unemployment')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Calculate total employed individuals for each region
total_employed_by_region = data.groupby('Region')['Estimated Employed'].sum()
total_employed_by_region
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(total_employed_by_region, labels=total_employed_by_region.index, autopct='%1.1f%%', startangle=140)
plt.title('Estimated Employed by Region')

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Show the pie chart
plt.show()

# %%
#Calculate total unemployment rate for each region over the months
total_unemprate_by_region = data.groupby('Region')['Estimated Unemployment Rate'].sum()
total_unemprate_by_region
# Out:
# Region
# East          556.64
# North        1255.28
# Northeast     416.11
# South         627.28
# West          411.95
# Name: Estimated Unemployment Rate, dtype: float64

# %%
# Group the data by state and calculate the average Estimated Labor Participation Rate
data.columns = ["States", "Date", "Frequency", "Estimated Unemployment Rate", "Estimated Employed", "Estimated Labor Participation Rate", "Region", "Longitude", "Latitude", "Month_Number", "Month_Name"]
data
average_rates = data.groupby('States')['Estimated Labor Participation Rate'].mean().reset_index()
average_rates
# Out:
#               States  Estimated Labor Participation Rate
# 0     Andhra Pradesh                           38.962000
# 1              Assam                           43.498000
# 2              Bihar                           37.173000
# 3       Chhattisgarh                           41.161000
# 4              Delhi                           35.857000
# 5                Goa                           39.242000
# 6            Gujarat                           45.490000
# 7            Haryana                           42.100000
# 8   Himachal Pradesh                           40.252000
# 9    Jammu & Kashmir                           37.894444
# 10         Jharkhand                           40.356000
# 11         Karnataka                           42.000000
# 12            Kerala                           33.382000
# 13    Madhya Pradesh                           38.926000
# 14       Maharashtra                           41.466000
# ...

# %%
# Group the data by state and calculate the average Estimated Labor Participation Rate
data.columns = ["States", "Date", "Frequency", "Estimated Unemployment Rate", "Estimated Employed", "Estimated Labor Participation Rate", "Region", "Longitude", "Latitude", "Month_Number", "Month_Name"]
data
average_rates = data.groupby('States')['Estimated Labor Participation Rate'].mean().reset_index()
# Plot the average rates for each state
plt.figure(figsize=(12, 6))
plt.bar(average_rates['States'], average_rates['Estimated Labor Participation Rate'], color='skyblue')
plt.xlabel('State')
plt.ylabel('Average Estimated Labor Participation Rate')
plt.title('Average Estimated Labor Participation Rate by State')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Group the data by state and calculate the average Estimated Unemployment Rate
data.columns = ["States", "Date", "Frequency", "Estimated Unemployment Rate", "Estimated Employed", "Estimated Labor Participation Rate", "Region", "Longitude", "Latitude", "Month_Number", "Month_Name"]
data
average_rates = data.groupby('States')['Estimated Unemployment Rate'].mean().reset_index()
average_rates
# Out:
#               States  Estimated Unemployment Rate
# 0     Andhra Pradesh                     8.664000
# 1              Assam                     4.856000
# 2              Bihar                    19.471000
# 3       Chhattisgarh                     7.819000
# 4              Delhi                    18.414000
# 5                Goa                    12.167000
# 6            Gujarat                     6.376000
# 7            Haryana                    27.477000
# 8   Himachal Pradesh                    16.065000
# 9    Jammu & Kashmir                    16.477778
# 10         Jharkhand                    19.539000
# 11         Karnataka                     7.668000
# 12            Kerala                     9.434000
# 13    Madhya Pradesh                     6.854000
# 14       Maharashtra                     7.979000
# 15         Meghalaya                     3.866000
# 16            Odisha                     6.462000
# 17        Puducherry                    17.942000
# ...

# %%
# Group the data by state and calculate the average Estimated Unemployment Rate
data.columns = ["States", "Date", "Frequency", "Estimated Unemployment Rate", "Estimated Employed", "Estimated Labor Participation Rate", "Region", "Longitude", "Latitude", "Month_Number", "Month_Name"]
data
average_rates = data.groupby('States')['Estimated Unemployment Rate'].mean().reset_index()
average_rates

# Plot the average rates for each state
plt.figure(figsize=(12, 6))
plt.bar(average_rates['States'], average_rates['Estimated Unemployment Rate'], color='magenta')
plt.xlabel('State')
plt.ylabel('Average Estimated Unemployment Rate')
plt.title('Average Estimated UnemploymentRate by State')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Group the data by state and calculate the average Estimated Employed
data.columns = ["States", "Date", "Frequency", "Estimated Unemployment Rate", "Estimated Employed", "Estimated Labor Participation Rate", "Region", "Longitude", "Latitude", "Month_Number", "Month_Name"]
data
average_rates = data.groupby('States')['Estimated Employed'].mean().reset_index()
average_rates["Estimated_Employed"] = average_rates["Estimated Employed"].apply(lambda x: "{:.2f}".format(x))
average_rates
# Out:
#               States  Estimated Employed Estimated_Employed
# 0     Andhra Pradesh        1.542548e+07        15425480.00
# 1              Assam        1.081028e+07        10810275.50
# 2              Bihar        2.360683e+07        23606828.00
# 3       Chhattisgarh        8.421349e+06         8421349.20
# 4              Delhi        4.632822e+06         4632821.90
# 5                Goa        4.423748e+05          442374.80
# 6            Gujarat        2.273075e+07        22730746.10
# 7            Haryana        6.844059e+06         6844059.00
# 8   Himachal Pradesh        2.033885e+06         2033884.90
# 9    Jammu & Kashmir        3.310032e+06         3310031.67
# 10         Jharkhand        8.770642e+06         8770642.40
# 11         Karnataka        2.162402e+07        21624017.60
# 12            Kerala        8.596795e+06         8596794.90
# 13    Madhya Pradesh        2.231834e+07        22318335.30
# 14       Maharashtra        3.920476e+07        39204758.20
# ...

# %%
average_rates = data.groupby('States')['Estimated Employed'].mean().reset_index()
average_rates["Estimated_Employed"] = average_rates["Estimated Employed"].apply(lambda x: "{:.2f}".format(x))
# Sort the DataFrame by the 'Estimated Employed' column
sorted_employed = average_rates.sort_values(by='Estimated Employed', ascending=False)

# Get the two states with maximum average estimated employed
max_states = sorted_employed.head(2)['States']

# Get the two states with minimum average estimated employed
min_states = sorted_employed.tail(2)['States']

# Print the results
print("Two states with maximum average estimated employed:", max_states.values)
print("Two states with minimum average estimated employed:", min_states.values)
# Out:
# Two states with maximum average estimated employed: ['Uttar Pradesh' 'Maharashtra']
# Two states with minimum average estimated employed: ['Puducherry' 'Sikkim']

# %% [markdown]
# We will now consider these four states Uttar pRadesh, Maharshtra, Puducherry, Sikkim for our further analysis

# %%
# Group the data by state and calculate the average Estimated Employed
data.columns = ["States", "Date", "Frequency", "Estimated Unemployment Rate", "Estimated Employed", "Estimated Labor Participation Rate", "Region", "Longitude", "Latitude", "Month_Number", "Month_Name"]
data
average_rates = data.groupby('States')['Estimated Employed'].mean().reset_index()
average_rates["Estimated_Employed"] = average_rates["Estimated Employed"].apply(lambda x: "{:.2f}".format(x))
average_rates

# Plot the average rates for each state
plt.figure(figsize=(12, 6))
plt.bar(average_rates['States'], average_rates['Estimated Employed'], color='purple')
plt.xlabel('State')
plt.ylabel('Average Estimated Employed')
plt.title('Average Estimated Employed by State')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
# Group the data by states
grouped_data = data.groupby('States')
print(grouped_data)

# %%
uttar_pradesh_data = data[data['States'] == 'Uttar Pradesh']
uttar_pradesh_data
# Out:
#             States       Date Frequency  Estimated Unemployment Rate  \
# 237  Uttar Pradesh 2020-01-31         M                         7.58
# 238  Uttar Pradesh 2020-02-29         M                         8.98
# 239  Uttar Pradesh 2020-03-31         M                        10.11
# 240  Uttar Pradesh 2020-04-30         M                        21.54
# 241  Uttar Pradesh 2020-05-31         M                        20.41
# 242  Uttar Pradesh 2020-06-30         M                         9.47
# 243  Uttar Pradesh 2020-07-31         M                         5.56
# 244  Uttar Pradesh 2020-08-31         M                         5.79
# 245  Uttar Pradesh 2020-09-30         M                         4.18
# 246  Uttar Pradesh 2020-10-31         M                         3.75
#
#      Estimated Employed  Estimated Labor Participation Rate Region  Longitude  \
# 237            59433759                               39.63  North    26.8467
# ...

# %%
uttar_pradesh_data = data[data['States'] == 'Uttar Pradesh']
uttar_pradesh_data
plt.figure(figsize=(10, 6))
plt.plot(uttar_pradesh_data["Date"], uttar_pradesh_data["Estimated Unemployment Rate"], marker='o', color='b', linestyle='-', label="Estimated Unemployment Rate")
plt.plot(uttar_pradesh_data["Date"], uttar_pradesh_data["Estimated Labor Participation Rate"], marker='o', color='r', linestyle='-', label="Estimated Labor Participation Rate")
plt.title(' Fluctuations in Uttar Pradesh')
plt.xlabel('Date')
plt.ylabel('Rate')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend()
plt.show()

# %%
maharashtra_data=data[data['States']=='Maharashtra']
maharashtra_data
plt.figure(figsize=(10, 6))
plt.plot(maharashtra_data["Date"], maharashtra_data["Estimated Unemployment Rate"], marker='o', color='b', linestyle='-', label="Estimated Unemployment Rate")
plt.plot(maharashtra_data["Date"], maharashtra_data["Estimated Labor Participation Rate"], marker='o', color='r', linestyle='-', label="Estimated Labor Participation Rate")
plt.title(' Fluctuations in Maharashtra')
plt.xlabel('Date')
plt.ylabel('Rate')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend()
plt.show()

# %%
puducherry_data=data[data['States']=='Puducherry']
puducherry_data
plt.figure(figsize=(10,6))
plt.plot(puducherry_data['Date'],puducherry_data['Estimated Unemployment Rate'],marker='o',color='b',linestyle='-',label="Estimated Unemployment Rate")
plt.plot(puducherry_data['Date'],puducherry_data['Estimated Labor Participation Rate'],marker='o',color='r',linestyle='-',label="Estimated Labor Participation Rate")
plt.title(' Fluctuations in Puducherry')
plt.xlabel('Date')
plt.ylabel('Rate')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend()
plt.show()

# %%
sikkim_data=data[data['States']=='Sikkim']
sikkim_data
plt.figure(figsize=(10,6))
plt.plot(sikkim_data['Date'],sikkim_data['Estimated Unemployment Rate'],marker='o',color='b',linestyle='-',label="Estimated Unemployment Rate")
plt.plot(sikkim_data['Date'],sikkim_data['Estimated Labor Participation Rate'],marker='o',color='r',linestyle='-',label="Estimated Labor Participation Rate")
plt.title(' Fluctuations in Sikkim')
plt.xlabel('Date')
plt.ylabel('Rate')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend()
plt.show()

# %%
#Create a dashboard to analyze unemployment rate of each Indian State by Region
#We will use sunburst plot
unemployment=data[['States',"Region","Estimated Unemployment Rate"]]
figure=px.sunburst(unemployment,path=["Region","States"],values="Estimated Unemployment Rate",
                   width=650,height=650,color_continuous_scale="blue",title="Unemployment Rate In India")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
